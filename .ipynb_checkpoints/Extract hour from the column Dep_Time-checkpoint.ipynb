# %%
#Extract hour from the column "Dep_Time" and create a new column based on the following conditions
#Dep_hour 0 to 4 ---> Late Night , 4-8 ----->Early Morning,  8-12 ----->Morning,  12-4 ----> Afternoon, 4-8 ---->Evening, 8-0 ----> Night
#Most Expensive Route
#Find Top 5 Airlines with Highest Average Ticket Price.

# %%
import pandas as pd

# %%
#Load the data
flight=pd.read_excel("/Users/cashify/Desktop/flight_price (1).xlsx")
flight
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
#Change the Object to Datetime
flight["Dep_Time"]=pd. to_datetime(flight["Dep_Time"])
print(flight["Dep_Time"].dtype)
# Out:
# datetime64[ns]

# %%
#To check the all columns dtype
print(flight.dtypes)
# Out:
# Airline                    object
# Date_of_Journey            object
# Source                     object
# Destination                object
# Route                      object
# Dep_Time           datetime64[ns]
# Arrival_Time               object
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %%
#To Showing first 10 record at the Dataset
print(flight["Dep_Time"].head(10))
# Out:
# 0   2026-08-02 22:20:00
# 1   2026-08-02 05:50:00
# 2   2026-08-02 09:25:00
# 3   2026-08-02 18:05:00
# 4   2026-08-02 16:50:00
# 5   2026-08-02 09:00:00
# 6   2026-08-02 18:55:00
# 7   2026-08-02 08:00:00
# 8   2026-08-02 08:55:00
# 9   2026-08-02 11:25:00
# Name: Dep_Time, dtype: datetime64[ns]

# %%
# Step 1: Extract hour (already converted above)
flight["Hour"]= flight["Dep_Time"].dt.hour
print(flight["Hour"].head(10))
# Out:
# 0    22
# 1     5
# 2     9
# 3    18
# 4    16
# 5     9
# 6    18
# 7     8
# 8     8
# 9    11
# Name: Hour, dtype: int32

# %%
def
