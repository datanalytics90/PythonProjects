# %%
#Extract hour from the column "Dep_Time" and create a new column based on the following conditions
#Dep_hour 0 to 4 ---> Late Night , 4-8 ----->Early Morning,  8-12 ----->Morning,  12-4 ----> Afternoon, 4-8 ---->Evening, 8-0 ----> Night
#Most Expensive Route
#Find Top 5 Airlines with Highest Average Ticket Price.

# %%
import pandas as pd

# %%
flight1= pd.read_excel("/Users/cashify/Desktop/Rahul’s MacBook/Personal Stuffs/Certification In Generative AI /Dataset(Python)/flight_price (1).xlsx")
flight1.head()
# Out:
# Running cells with 'Python 3.15.0' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/Users/cashify/.local/bin/python3.15 -m pip install ipykernel -U --user --force-reinstall'
