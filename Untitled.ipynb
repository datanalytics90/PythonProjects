# %%
try:
    lst_1=[1,2,3,4,"Kolkata","Patna"]
    print(lst_1[4])
except IndexError:
    print("Provide Valid Index")
finally:
    print("This is an Indexing")
# Out:
# Kolkata
# This is an Indexing
