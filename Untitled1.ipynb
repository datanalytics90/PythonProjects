# %%
age=int(input("Enter your age:"))
if age>18:
    print("You are eligible for voting")
else:
    print("You are not eligible for voting")
# Out:
# Enter your age: 34
# You are eligible for voting

# %%
#Create a program that takes two numbers as input and prints their sum, difference, and product.
num1=int(input("Enter your first number: "))
num2=int(input("Enter your second number: "))
print("The sum is:", num1+num2)
print("Diferrence between two numbers is:", num1-num2)
print("The product of the tow numbers is:", num1*num2)
# Out:
# Enter your first number:  4
# Enter your second number:  5
# The sum is: 9
# Diferrence between two numbers is: -1
# The product of the tow numbers is: 20

# %%
num3=int(input("Enter a number:"))
if num3 % 2 == 0:
    print(f"{num3} is Even")
else:
    print(f"{num3} is Odd")
# Out:
# Enter a number: 3
# 3 is Odd

# %%
x=10
y=5

print(f"Before Swapping: x={x} , y={y}")

temp = x

x = y

y = temp

print(f"After Swapping: x={x} , y={y}")
# Out:
# Before Swapping: x=10 , y=5
# After Swapping: x=5 , y=10

# %%
name= input("Enter your name:")

if len("name") > 0:
    print(f"First Character is {name[0]}, Last Character is {name[1]}")
else:
    print("The name is empty value")
# Out:
# Enter your name: Rahul
# First Character is R, Last Character is a
