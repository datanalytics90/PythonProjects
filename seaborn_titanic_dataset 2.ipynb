# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df= sns.load_dataset("titanic")
print(df.shape)
df.head()
df.info()
df.describe(include="all")
# Out:
# (891, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# ...

# %%
(df.isnull().sum()/len(df))*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
print(df.isnull().sum().sum())
# Out:
# 869

# %%
#Count Survivors
survival_counts = titanic['survived'].value_counts()
print("Survival Counts:")
print(survival_counts)
# Out:
# Survival Counts:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
#Calculate Totals
total = len(titanic)
survived = survival_counts[0]
notsurvived = survival_counts[1]

# %%
#Calculate Percentages
survival_rate = (survived/total)*100
notsurvival_rate = (notsurvived/total)*100

# %%
print("\n" + "="*50)
print("TITANIC SURVIVAL ANALYSIS")
print("="*50)
print(f"Survived: {survived} passengers ({survival_rate:.2f}%)")
print(f"Did Not Survive: {notsurvived} passengers ({notsurvival_rate:.2f}%)")
print(f"Total Passengers: {total}")
print("="*50)
# Out:
# ...
# TITANIC SURVIVAL ANALYSIS
# ...
# Survived: 549 passengers (61.62%)
# Did Not Survive: 342 passengers (38.38%)
# Total Passengers: 891
# ...

# %%
#Data Visualization
plt.figure(figsize=(20,10), facecolor="blue")
#Titanic Survival Count - Plot 1
titanic=sns.countplot(x="survived",data=titanic,hue="sex", palette="set2")
plt.title("Titanic Survival Count",fontweight="bold", fontsize=18)
plt.xlabel('Survived (0=No, 1=Yes)',fontweight="bold", fontsize=16)
plt.ylabel("Number Of Passengers", fontweight="bold", fontsize=16)
plt.gca().patch.set_facecolor("lightblue")
plt.legend(title='Gender', labels=['Male', 'Female'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       2 plt.figure(figsize=(20,10), facecolor="blue")
#       3 #Titanic Survival Count - Plot 1
# ----> 4 titanic=sns.countplot(x="survived",data=titanic,hue="sex", palette="set2")
#       5 plt.title("Titanic Survival Count",fontweight="bold", fontsize=18)
#       6 plt.xlabel('Survived (0=No, 1=Yes)',fontweight="bold", fontsize=16)
#
# NameError: name 'titanic' is not defined

# %%
titanic=sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Histogram Plot based on age distribution
plt.figure(figsize=(8,4),facecolor="lightblue")
sns.histplot(x="age",data=titanic,bins=20,kde=True)
plt.xlabel("age",color="red",fontsize=12,fontweight="bold")
plt.show()
