# %%
print("Hello Rahul")
# Out:
# Hello Rahul

# %%
import sys
import pandas as pd
import numpy as np

print(sys.executable)
print(pd.__version__)
print(np.__version__)
# Out:
# /opt/miniconda3/envs/datascience/bin/python
# 2.3.1
# 2.0.1
